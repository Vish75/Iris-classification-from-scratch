# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanSquaredLogarithmicError

# %%
l = pd.read_csv('data .csv')
l
# Out:
#         C1     C2  Op         Res
# 0     1+5j   2+2j   0        3+7j
# 1        1      2   0           3
# 2       5j     2j   0          7j
# 3        5   3+8j   0        8+8j
# 4     9+2j      2   0       11+2j
# 5        1     6j   0        1+6j
# 6     8+3j   2+2j   0       10+5j
# 7        3      0   0           3
# 8     34+j     7j   0       34+8j
# 9     1+5j   2+2j   1       -1+3j
# 10      5j     2j   1          3j
# 11       7      3   1           4
# 12     23j      5   1      -5+23j
# 13      19     2j   1       19-2j
# 14   12+7j      9   1        3+7j
# 15  93+17j  22+6j   1      71+11j
# 16      93   2+2j   1       91+2j
# 17   11+9j   3+4j   1        8+5j
# 18      3j   2+5j   1        2-2j
# 19  18+13j  6+14j   1        12-j
# 20    2+3j   5+5j   2      -5+25j
# 21       2      5   2          10
# 22      3j     7j   2         21j
# 23       6     9j   2         54j
# 24      2j      4   2          8j
# 25     -25     9j   2       -225j
# ...

# %%
X = l.iloc[:,0:3]
y = l.iloc[:,-1]
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=22)

# %%
X
# Out:
#         C1     C2  Op
# 0     1+5j   2+2j   0
# 1        1      2   0
# 2       5j     2j   0
# 3        5   3+8j   0
# 4     9+2j      2   0
# 5        1     6j   0
# 6     8+3j   2+2j   0
# 7        3      0   0
# 8     34+j     7j   0
# 9     1+5j   2+2j   1
# 10      5j     2j   1
# 11       7      3   1
# 12     23j      5   1
# 13      19     2j   1
# 14   12+7j      9   1
# 15  93+17j  22+6j   1
# 16      93   2+2j   1
# 17   11+9j   3+4j   1
# 18      3j   2+5j   1
# 19  18+13j  6+14j   1
# 20    2+3j   5+5j   2
# 21       2      5   2
# 22      3j     7j   2
# 23       6     9j   2
# 24      2j      4   2
# 25     -25     9j   2
# 26    -9-j   7+2j   2
# 27    -1-j   2+3j   2
# 28    -25j     3j   2
# 29    9-5j  6+14j   2
# 30    2+2j   4+4j   3
# 31    2+2j     4j   3
# 32       2   4+4j   3
# 33    2+5j   5+7j   3
# 34   9+12j      8   3
# 35   10-5j    1+j   3
# 36   10-5j  -5+5j   3
# 37     1+j   6-5j   3
# 38      12   3-8j   3
# 39      6j   4+3j   3

# %%
model = Sequential([
    Dense(3, activation='relu', input_shape=(3,)),
    Dense(1, activation='linear'),
])

# %%
model.compile(optimizer=Adam(learning_rate=0.01),
             loss = MeanSquaredLogarithmicError(),
             metrics= [MeanSquaredLogarithmicError()])

# %%
X_train=np.asarray(X_train).astype(np.complex_)

y_train=np.asarray(y_train).astype(np.complex_)

# %%
model.fit(X_train, y_train,
          batch_size=5, epochs=100)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 1s 3ms/step - loss: 3.9196 - mean_squared_logarithmic_error: 3.6947
# Epoch 2/100
# 7/7 [==============================] - 0s 3ms/step - loss: 3.2758 - mean_squared_logarithmic_error: 4.0987
# Epoch 3/100
# 7/7 [==============================] - 0s 5ms/step - loss: 2.7991 - mean_squared_logarithmic_error: 2.6647
# Epoch 4/100
# 7/7 [==============================] - 0s 4ms/step - loss: 2.4356 - mean_squared_logarithmic_error: 2.3697
# Epoch 5/100
# 7/7 [==============================] - 0s 8ms/step - loss: 2.1658 - mean_squared_logarithmic_error: 2.2269
# Epoch 6/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.9983 - mean_squared_logarithmic_error: 1.9361
# Epoch 7/100
# 7/7 [==============================] - 0s 4ms/step - loss: 1.8931 - mean_squared_logarithmic_error: 1.7524
# Epoch 8/100
# 7/7 [==============================] - 0s 4ms/step - loss: 1.7992 - mean_squared_logarithmic_error: 2.0864
# Epoch 9/100
# ...

# %%
X_test=np.asarray(X_test).astype(np.complex_)
y_test=np.asarray(y_test).astype(np.complex_)
y_pred = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 55ms/step

# %%
y_pred
# Out:
# array([[ 1.3583841 ],
#        [ 5.5018797 ],
#        [ 0.48229492],
#        [ 2.0917935 ],
#        [ 0.20055479],
#        [ 1.156718  ],
#        [ 0.20055479],
#        [53.758274  ]], dtype=float32)

# %%
y_pred_new = model.predict(X_train)
# Out:
# 1/1 [==============================] - 0s 35ms/step

# %%
y_pred_new
# Out:
# array([[ 0.20055479],
#        [ 1.2561529 ],
#        [ 1.346308  ],
#        [ 3.9845128 ],
#        [10.481471  ],
#        [ 3.972812  ],
#        [ 3.5154543 ],
#        [ 0.3408214 ],
#        [ 5.2114673 ],
#        [ 6.3015127 ],
#        [ 0.3408214 ],
#        [-0.7503825 ],
#        [54.593     ],
#        [ 1.0732453 ],
#        [ 2.5906126 ],
#        [ 4.2599072 ],
#        [ 0.46727693],
#        [ 0.71395296],
#        [ 2.2317452 ],
#        [-1.309205  ],
#        [ 0.52274346],
#        [10.810303  ],
#        [ 2.0917935 ],
#        [ 7.1311803 ],
#        [ 0.47162792],
#        [ 4.57878   ],
#        [ 1.9098713 ],
#        [20.18849   ],
#        [ 0.48229492],
#        [ 4.009489  ],
#        [ 1.156718  ],
#        [ 5.790717  ]], dtype=float32)
